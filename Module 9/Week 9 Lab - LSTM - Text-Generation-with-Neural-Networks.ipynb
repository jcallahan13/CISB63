# %% [markdown]
# # LAB Text Generation with Neural Networks

# %% [markdown]
# ## Functions for Processing Text
#
# ### Reading in files as a string text

# %%
def read_file(filepath):
    
    with open(filepath) as f:
        str_text = f.read()
    
    return str_text

# %% [markdown]
# #### Call the function below and read teh file: moby_dick_four_chapters.txt

# %%
read_file('moby_dick_four_chapters.txt')
# Out:
# 'Call me Ishmael.  Some years ago--never mind how long\nprecisely--having little or no money in my purse, and nothing\nparticular to interest me on shore, I thought I would sail about a\nlittle and see the watery part of the world.  It is a way I have of\ndriving off the spleen and regulating the circulation.  Whenever I\nfind myself growing grim about the mouth; whenever it is a damp,\ndrizzly November in my soul; whenever I find myself involuntarily\npausing before coffin warehouses, and bringing up the rear of every\nfuneral I meet; and especially whenever my hypos get such an upper\nhand of me, that it requires a strong moral principle to prevent me\nfrom deliberately stepping into the street, and methodically knocking\npeople\'s hats off--then, I account it high time to get to sea as soon\nas I can.  This is my substitute for pistol and ball.  With a\nphilosophical flourish Cato throws himself upon his sword; I quietly\ntake to the ship.  There is nothing surprising in this.  If they but\nknew it, almost all men in their degree, some time or other, cherish\nvery nearly the same feelings towards the ocean with me.\n\nThere now is your insular city of the Manhattoes, belted round by\nwharves as Indian isles by coral reefs--commerce surrounds it with\nher surf.  Right and left, the streets take you waterward.  Its\nextreme downtown is the battery, where that noble mole is washed by\nwaves, and cooled by breezes, which a few hours previous were out of\nsight of land.  Look at the crowds of water-gazers there.\n\nCircumambulate the city of a dreamy Sabbath afternoon.  Go from\nCorlears Hook to Coenties Slip, and from thence, by Whitehall,\nnorthward.  What do you see?--Posted like silent sentinels all around\nthe town, stand thousands upon thousands of mortal men fixed in ocean\nreveries.  Some leaning against the spiles; some seated upon the\npier-heads; some looking over the bulwarks of ships from China; some\nhigh aloft in the rigging, as if striving to get a still better\nseaward peep.  But these are all landsmen; of week days pent up in\nlath and plaster--tied to counters, nailed to benches, clinched to\ndesks.  How then is this?  Are the green fields gone?  What do they\nhere?\n\nBut look! here come more crowds, pacing straight for the water, and\nseemingly bound for a dive.  Strange!  Nothing will content them but\nthe extremest limit of the land; loitering under the shady lee of\nyonder warehouses will not suffice.  No.  They must get just as nigh\nthe water as they possibly can without falling in.  And there they\nstand--miles of them--leagues.  Inlanders all, they come from lanes\nand alleys, streets and avenues--north, east, south, and west.  Yet\nhere they all unite.  Tell me, does the magnetic virtue of the\nneedles of the compasses of all those ships attract them thither?\n\nOnce more.  Say you are in the country; in some high land of lakes.\nTake almost any path you please, and ten to one it carries you down\nin a dale, and leaves you there by a pool in the stream.  There is\nmagic in it.  Let the most absent-minded of men be plunged in his\ndeepest reveries--stand that man on his legs, set his feet a-going,\nand he will infallibly lead you to water, if water there be in all\nthat region.  Should you ever be athirst in the great American\ndesert, try this experiment, if your caravan happen to be supplied\nwith a metaphysical professor.  Yes, as every one knows, meditation\nand water are wedded for ever.\n\nBut here is an artist.  He desires to paint you the dreamiest,\nshadiest, quietest, most enchanting bit of romantic landscape in all\nthe valley of the Saco.  What is the chief element he employs?  There\nstand his trees, each with a hollow trunk, as if a hermit and a\ncrucifix were within; and here sleeps his meadow, and there sleep his\ncattle; and up from yonder cottage goes a sleepy smoke.  Deep into\ndistant woodlands winds a mazy way, reaching to overlapping spurs of\nmountains bathed in their hill-side  ...

# %% [markdown]
# #### import spacy

# %%
import spacy

# %% [markdown]
# #### load: en_core_web_sm and assign it to a variable call "nlp"

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# #### Let's calculate the length

# %%
nlp.max_length = 1198623

# %% [markdown]
# #### create a function to separate punctuation

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
#### call the function read_file and read the file: melville-moby_dick.txt and save it in a variable called "d"

# %%
d = read_file('melville-moby_dick.txt')

# %%
#### using a variable called tokens, call the separate_punc function. Send "d" as a parameter

# %%
tokens = separate_punc(d)

# %% [markdown]
# #### List the tokens

# %%
tokens
# Out:
# ['chapter',
#  '1',
#  'loomings',
#  'call',
#  'me',
#  'ishmael',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me',
#  'on',
#  'shore',
#  'i',
#  'thought',
#  'i',
#  'would',
#  'sail',
#  'about',
#  'a',
#  'little',
#  'and',
#  'see',
#  'the',
#  'watery',
#  'part',
#  'of',
#  'the',
#  'world',
#  'it',
#  'is',
#  'a',
#  'way',
#  'i',
#  'have',
#  'of',
#  'driving',
#  'off',
#  'the',
#  'spleen',
#  'and',
#  'regulating',
#  'the',
#  'circulation',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'growing',
#  'grim',
#  'about',
#  'the',
#  'mouth',
#  'whenever',
#  'it',
#  'is',
#  'a',
#  'damp',
#  'drizzly',
#  'november',
#  'in',
#  'my',
#  'soul',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'involuntarily',
#  'pausing',
#  'before',
#  'coffin',
#  'warehouses',
#  'and',
#  'bringing',
#  'up',
#  'the',
#  'rear',
#  'of',
#  'every',
#  'funeral',
#  'i',
#  'meet',
#  'and',
#  'especially',
#  'whenever',
#  'my',
#  'hypos',
#  'get',
#  'such',
#  'an',
#  'upper',
#  'hand',
#  'of',
#  'me',
#  'that',
#  'it',
#  'requires',
#  'a',
#  'strong',
#  'moral',
#  'principle',
#  'to',
#  'prevent',
#  'me',
#  'from',
#  'deliberately',
#  'stepping',
#  'into',
#  'the',
#  'street',
#  'and',
#  'methodically',
#  'knocking',
#  'people',
#  "'s",
#  'hats',
#  'off',
#  'then',
#  'i',
#  'account',
#  'it',
#  'high',
#  'time',
#  'to',
#  'get',
#  'to',
#  'sea',
#  'as',
#  'soon',
#  'as',
#  'i',
#  'can',
#  'this',
#  'is',
#  'my',
#  'substitute',
#  'for',
#  'pistol',
#  'and',
#  'ball',
#  'with',
#  'a',
#  'philosophical',
#  'flourish',
#  'cato',
#  'throws',
#  'himself',
#  'upon',
#  'his',
#  'sword',
#  'i',
#  'quietly',
#  'take',
#  'to',
#  'the',
#  'ship',
#  'there',
#  'is',
#  'nothing',
#  'surprising',
#  'in',
#  'this',
#  'if',
#  'they',
#  'but',
#  'knew',
#  'it',
#  'almost',
#  'all',
#  'men',
#  'in',
#  'their',
#  'degree',
#  'some',
#  'time',
#  'or',
#  'other',
#  'cherish',
#  'very',
#  'nearly',
#  'the',
#  'same',
#  'feelings',
#  'towards',
#  'the',
#  'ocean',
#  'with',
#  'me',
#  'there',
#  'now',
#  'is',
#  'your',
#  'insular',
#  'city',
#  'of',
#  'the',
#  'manhattoes',
#  'belted',
#  'round',
#  'by',
#  'wharves',
#  'as',
#  'indian',
#  'isles',
#  'by',
#  'coral',
#  'reefs',
#  'commerce',
#  'surrounds',
#  'it',
#  'with',
#  'her',
#  'surf',
#  'right',
#  'and',
#  'left',
#  'the',
#  'streets',
#  'take',
#  'you',
#  'waterward',
#  'its',
#  'extreme',
#  'downtown',
#  'is',
#  'the',
#  'battery',
#  'where',
#  'that',
#  'noble',
#  'mole',
#  'is',
#  'washed',
#  'by',
#  'waves',
#  'and',
#  'cooled',
#  'by',
#  'breezes',
#  'which',
#  'a',
#  'few',
#  'hours',
#  'previous',
#  'were',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'look',
#  'at',
#  'the',
#  'crowds',
#  'of',
#  'water',
#  'gazers',
#  'there',
#  'circumambulate',
#  'the',
#  'city',
#  'of',
#  'a',
#  'dreamy',
#  'sabbath',
#  'afternoon',
#  'go',
#  'from',
#  'corlears',
#  'hook',
#  'to',
#  'coenties',
#  'slip',
#  'and',
#  'from',
#  'thence',
#  'by',
#  'whitehall',
#  'northward',
#  'what',
#  'do',
#  'you',
#  'see?--posted',
#  'like',
#  'silent',
#  'sentinels',
#  'all',
#  'around',
#  'the',
#  'town',
#  'stand',
#  'thousands',
#  'upon',
#  'thousands',
#  'of',
#  'mortal',
#  'men',
#  'fixed',
#  'in',
#  'ocean',
#  'reveries',
#  'some',
#  'leaning',
#  'against',
#  'the',
#  'spiles',
#  'some',
#  'seated',
#  'upon',
#  'the',
#  'pier',
#  'heads',
#  'some',
#  'looking',
#  'over',
#  'the',
#  'bulwarks',
#  'of',
#  'ships',
#  'from',
#  'china',
#  'some',
#  'high',
#  'aloft',
#  'in',
#  'the',
#  'rigging',
#  'as',
#  'if',
#  'striving',
#  'to',
#  'get',
#  'a',
#  'still',
#  'better',
#  'seaward',
#  'peep',
#  'but',
#  'these',
#  'are',
#  'all',
#  'landsmen',
#  'of',
#  'week',
#  'days',
#  'pent',
#  'up',
#  'in',
#  'lath',
#  'and',
#  'plaster',
#  'tied',
#  'to',
#  'counters',
#  'nailed',
#  'to',
#  'benches',
#  'clinched',
#  'to',
#  'desks',
#  'how',
#  'then',
#  'is',
#  'this',
#  'are',
#  'the',
#  'green',
#  'fields',
#  'gone',
#  'what',
#  'do',
#  'they',
#  'here',
#  'but',
#  'look',
#  'here',
#  'come',
#  'more',
#  'crowds',
#  'pacing',
#  'straight',
#  'for',
#  'the',
#  'water',
#  'and',
#  'seemingly',
#  'bound',
#  'for',
#  'a',
#  'dive',
#  'strange',
#  'nothing',
#  'will',
#  'content',
#  'them',
#  'but',
#  'the',
#  'extremest',
#  'limit',
#  'of',
#  'the',
#  'land',
#  'loitering',
#  'under',
#  'the',
#  'shady',
#  'lee',
#  'of',
#  'yonder',
#  'warehouses',
#  'will',
#  'not',
#  'suffice',
#  'no',
#  'they',
#  'must',
#  'get',
#  'just',
#  'as',
#  'nigh',
#  'the',
#  'water',
#  'as',
#  'they',
#  'possibly',
#  'can',
#  'without',
#  'falling',
#  'in',
#  'and',
#  'there',
#  'they',
#  'stand',
#  'miles',
#  'of',
#  'them',
#  'leagues',
#  'inlanders',
#  'all',
#  'they',
#  'come',
#  'from',
#  'lanes',
#  'and',
#  'alleys',
#  'streets',
#  'and',
#  'avenues',
#  'north',
#  'east',
#  'south',
#  'and',
#  'west',
#  'yet',
#  'here',
#  'they',
#  'all',
#  'unite',
#  'tell',
#  'me',
#  'does',
#  'the',
#  'magnetic',
#  'virtue',
#  'of',
#  'the',
#  'needles',
#  'of',
#  'the',
#  'compasses',
#  'of',
#  'all',
#  'those',
#  'ships',
#  'attract',
#  'them',
#  'thither',
#  'once',
#  'more',
#  'say',
#  'you',
#  'are',
#  'in',
#  'the',
#  'country',
#  'in',
#  'some',
#  'high',
#  'land',
#  'of',
#  'lakes',
#  'take',
#  'almost',
#  'any',
#  'path',
#  'you',
#  'please',
#  'and',
#  'ten',
#  'to',
#  'one',
#  'it',
#  'carries',
#  'you',
#  'down',
#  'in',
#  'a',
#  'dale',
#  'and',
#  'leaves',
#  'you',
#  'there',
#  'by',
#  'a',
#  'pool',
#  'in',
#  'the',
#  'stream',
#  'there',
#  'is',
#  'magic',
#  'in',
#  'it',
#  'let',
#  'the',
#  'most',
#  'absent',
#  'minded',
#  'of',
#  'men',
#  'be',
#  'plunged',
#  'in',
#  'his',
#  'deepest',
#  'reveries',
#  'stand',
#  'that',
#  'man',
#  'on',
#  'his',
#  'legs',
#  'set',
#  'his',
#  'feet',
#  'a',
#  'going',
#  'and',
#  'he',
#  'will',
#  'infallibly',
#  'lead',
#  'you',
#  'to',
#  'water',
#  'if',
#  'water',
#  'there',
#  'be',
#  'in',
#  'all',
#  'that',
#  'region',
#  'should',
#  'you',
#  'ever',
#  'be',
#  'athirst',
#  'in',
#  'the',
#  'great',
#  'american',
#  'desert',
#  'try',
#  'this',
#  'experiment',
#  'if',
#  'your',
#  'caravan',
#  'happen',
#  'to',
#  'be',
#  'supplied',
#  'with',
#  'a',
#  'metaphysical',
#  'professor',
#  'yes',
#  'as',
#  'every',
#  'one',
#  'knows',
#  'meditation',
#  'and',
#  'water',
#  'are',
#  'wedded',
#  'for',
#  'ever',
#  'but',
#  'here',
#  'is',
#  'an',
#  'artist',
#  'he',
#  'desires',
#  'to',
#  'paint',
#  'you',
#  'the',
#  'dreamiest',
#  'shadiest',
#  'quietest',
#  'most',
#  'enchanting',
#  'bit',
#  'of',
#  'romantic',
#  'landscape',
#  'in',
#  'all',
#  'the',
#  'valley',
#  'of',
#  'the',
#  'saco',
#  'what',
#  'is',
#  'the',
#  'chief',
#  'element',
#  'he',
#  'employs',
#  'there',
#  'stand',
#  'his',
#  'trees',
#  'each',
#  'with',
#  'a',
#  'hollow',
#  'trunk',
#  'as',
#  'if',
#  'a',
#  'hermit',
#  'and',
#  'a',
#  'crucifix',
#  'were',
#  'within',
#  'and',
#  'here',
#  'sleeps',
#  'his',
#  'meadow',
#  'and',
#  'there',
#  'sleep',
#  'his',
#  'cattle',
#  'and',
#  'up',
#  'from',
#  'yonder',
#  'cottage',
#  'goes',
#  'a',
#  'sleepy',
#  'smoke',
#  'deep',
#  'into',
#  'distant',
#  'woodlands',
#  'winds',
#  'a',
#  'mazy',
#  'way',
#  'reaching',
#  'to',
#  'overlapping',
#  'spurs',
#  'of',
#  'mountains',
#  'bathed',
#  'in',
#  'their',
#  'hill',
#  'side',
#  'blue',
#  'but',
#  'though',
#  'the',
#  'picture',
#  'lies',
#  'thus',
#  'tranced',
#  'and',
#  'though',
#  'this',
#  'pine',
#  'tree',
#  'shakes',
#  'down',
#  'its',
#  'sighs',
#  'like',
#  'leaves',
#  'upon',
#  'this',
#  'shepherd',
#  "'s",
#  'head',
#  'yet',
#  'all',
#  'were',
#  'vain',
#  'unless',
#  'the',
#  'shepherd',
#  "'s",
#  'eye',
#  'were',
#  'fixed',
#  'upon',
#  'the',
#  'magic',
#  'stream',
#  'before',
#  'him',
#  'go',
#  'visit',
#  'the',
#  'prairies',
#  'in',
#  'june',
#  'when',
#  'for',
#  'scores',
#  'on',
#  'scores',
#  'of',
#  'miles',
#  'you',
#  'wade',
#  'knee',
#  'deep',
#  'among',
#  'tiger',
#  'lilies',
#  'what',
#  'is',
#  'the',
#  'one',
#  'charm',
#  'wanting?--water',
#  'there',
#  'is',
#  'not',
#  'a',
#  'drop',
#  'of',
#  'water',
#  'there',
#  'were',
#  'niagara',
#  'but',
#  'a',
#  'cataract',
#  'of',
#  'sand',
#  'would',
#  'you',
#  'travel',
#  'your',
#  'thousand',
#  'miles',
#  'to',
#  'see',
#  'it',
#  'why',
#  'did',
#  'the',
#  'poor',
#  'poet',
#  'of',
#  'tennessee',
#  'upon',
#  'suddenly',
#  'receiving',
#  'two',
#  'handfuls',
#  'of',
#  'silver',
#  'deliberate',
#  'whether',
#  'to',
#  'buy',
#  'him',
#  'a',
#  'coat',
#  'which',
#  'he',
#  'sadly',
#  'needed',
#  'or',
#  'invest',
#  'his',
#  'money',
#  'in',
#  'a',
#  'pedestrian',
#  'trip',
#  'to',
#  'rockaway',
#  'beach',
#  'why',
#  'is',
#  'almost',
#  'every',
#  'robust',
#  'healthy',
#  'boy',
#  'with',
#  'a',
#  'robust',
#  'healthy',
#  'soul',
#  'in',
#  'him',
#  'at',
#  'some',
#  'time',
#  'or',
#  'other',
#  'crazy',
#  'to',
#  'go',
#  'to',
#  'sea',
#  'why',
#  'upon',
#  'your',
#  'first',
#  'voyage',
#  'as',
#  'a',
#  'passenger',
#  'did',
#  'you',
#  'yourself',
#  'feel',
#  'such',
#  'a',
#  'mystical',
#  'vibration',
#  'when',
#  'first',
#  'told',
#  'that',
#  'you',
#  'and',
#  'your',
#  'ship',
#  'were',
#  'now',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'why',
#  'did',
#  'the',
#  'old',
#  'persians',
#  'hold',
#  'the',
#  'sea',
#  'holy',
#  'why',
#  'did',
#  'the',
#  'greeks',
#  'give',
#  'it',
#  'a',
#  'separate',
#  'deity',
#  'and',
#  'own',
#  'brother',
#  'of',
#  'jove',
#  'surely',
#  'all',
#  'this',
#  'is',
#  'not',
#  'without',
#  'meaning',
#  'and',
#  'still',
#  'deeper',
#  'the',
#  'meaning',
#  'of',
#  'that',
#  'story',
#  'of',
#  'narcissus',
#  'who',
#  'because',
#  'he',
#  'could',
#  'not',
#  'grasp',
#  'the',
#  'tormenting',
#  'mild',
#  'image',
#  'he',
#  'saw',
#  'in',
#  'the',
#  'fountain',
#  'plunged',
#  'into',
#  'it',
#  'and',
#  'was',
#  'drowned',
#  'but',
#  'that',
#  'same',
#  'image',
#  'we',
#  'ourselves',
#  'see',
#  'in',
#  'all',
#  'rivers',
#  'and',
#  'oceans',
#  'it',
#  'is',
#  'the',
#  'image',
#  'of',
#  'the',
#  'ungraspable',
#  'phantom',
#  'of',
#  'life',
#  'and',
#  'this',
#  'is',
#  'the',
#  'key',
#  'to',
#  'it',
#  'all',
#  'now',
#  'when',
#  'i',
#  'say',
#  'that',
#  'i',
#  'am',
#  'in',
#  'the',
#  'habit',
#  'of',
#  'going',
#  'to',
#  'sea',
#  'whenever',
#  'i',
#  'begin',
#  'to',
#  'grow',
#  'hazy',
#  'about',
#  ...]

# %% [markdown]
# #### Get the lenght of tokens

# %%
len(tokens)
# Out:
# 214708

# %%
4431/25
# Out:
# 177.24

# %% [markdown]
# ## Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %% [markdown]
# #### using ' '.join() display the words of the first sequence [0]

# %%
' '.join(text_sequences[0])
# Out:
# 'chapter 1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to'

# %% [markdown]
# #### display the words of the second sequence [1]

# %%
' '.join(text_sequences[1])
# Out:
# '1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest'

# %% [markdown]
# #### display the words of the third one

# %%
' '.join(text_sequences[2])
# Out:
# 'loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me'

# %% [markdown]
# #### get the length of text_sequences

# %%
len(text_sequences)
# Out:
# 214682

# %% [markdown]
# # Keras

# %% [markdown]
# ### Keras Tokenization

# %% [markdown]
# #### import Tokenizer from Keras...

# %%
#!pip uninstall tensorflow
#!pip install tensorflow==2.12.0
import tensorflow as tf
import keras
from keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %% [markdown]
# #### List the sequences[0]

# %%
sequences[0]
# Out:
# [158,
#  9443,
#  17526,
#  402,
#  42,
#  1043,
#  43,
#  247,
#  659,
#  140,
#  296,
#  116,
#  82,
#  787,
#  347,
#  113,
#  36,
#  50,
#  1788,
#  6,
#  49,
#  3028,
#  3,
#  218,
#  442,
#  5]

# %% [markdown]
# #### display the tokenizer.index_word

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'to',
#  6: 'in',
#  7: 'that',
#  8: 'his',
#  9: 'it',
#  10: 'i',
#  11: 'he',
#  12: 'but',
#  13: "'s",
#  14: 'as',
#  15: 'with',
#  16: 'is',
#  17: 'was',
#  18: 'for',
#  19: 'all',
#  20: 'this',
#  21: 'at',
#  22: 'not',
#  23: 'by',
#  24: 'whale',
#  25: 'from',
#  26: 'so',
#  27: 'him',
#  28: 'on',
#  29: 'be',
#  30: 'one',
#  31: 'you',
#  32: 'there',
#  33: 'now',
#  34: 'had',
#  35: 'have',
#  36: 'or',
#  37: 'were',
#  38: 'they',
#  39: 'like',
#  40: 'which',
#  41: 'then',
#  42: 'me',
#  43: 'some',
#  44: 'their',
#  45: 'what',
#  46: 'when',
#  47: 'an',
#  48: 'are',
#  49: 'my',
#  50: 'no',
#  51: 'upon',
#  52: 'out',
#  53: 'man',
#  54: 'into',
#  55: 'ship',
#  56: 'up',
#  57: 'more',
#  58: 'ahab',
#  59: 'if',
#  60: 'them',
#  61: 'old',
#  62: 'we',
#  63: 'sea',
#  64: 'would',
#  65: "'",
#  66: 'ye',
#  67: 'do',
#  68: 'other',
#  69: 'been',
#  70: 'over',
#  71: 'these',
#  72: 'will',
#  73: 'though',
#  74: 'only',
#  75: 'its',
#  76: 'down',
#  77: 'such',
#  78: 'who',
#  79: 'yet',
#  80: 'head',
#  81: 'time',
#  82: 'long',
#  83: 'boat',
#  84: 'her',
#  85: 'any',
#  86: 'captain',
#  87: 'very',
#  88: 'here',
#  89: 'still',
#  90: 'about',
#  91: 'those',
#  92: 'than',
#  93: 'before',
#  94: 'great',
#  95: 'two',
#  96: 'has',
#  97: 'said',
#  98: 'did',
#  99: 'seemed',
#  100: 'must',
#  101: 'white',
#  102: 'last',
#  103: 'most',
#  104: 'way',
#  105: 'after',
#  106: 'thou',
#  107: 'can',
#  108: 'see',
#  109: 'again',
#  110: 'stubb',
#  111: "n't",
#  112: 'queequeg',
#  113: 'little',
#  114: 'whales',
#  115: 'round',
#  116: 'how',
#  117: 'your',
#  118: 'three',
#  119: 'while',
#  120: 'men',
#  121: 'sperm',
#  122: 'say',
#  123: 'may',
#  124: 'first',
#  125: 'every',
#  126: 'well',
#  127: 'through',
#  128: 'us',
#  129: 'much',
#  130: 'could',
#  131: 'being',
#  132: 'off',
#  133: 'good',
#  134: 'same',
#  135: 'where',
#  136: 'hand',
#  137: 'side',
#  138: 'own',
#  139: 'our',
#  140: 'never',
#  141: 'himself',
#  142: 'ever',
#  143: 'look',
#  144: 'starbuck',
#  145: 'deck',
#  146: 'almost',
#  147: 'go',
#  148: 'even',
#  149: 'thing',
#  150: 'water',
#  151: 'too',
#  152: 'away',
#  153: 'might',
#  154: 'should',
#  155: 'made',
#  156: 'come',
#  157: 'day',
#  158: 'chapter',
#  159: 'pequod',
#  160: 'world',
#  161: 'life',
#  162: 'among',
#  163: 'far',
#  164: 'many',
#  165: 'fish',
#  166: 'back',
#  167: 'seen',
#  168: 'line',
#  169: 'let',
#  170: 'eyes',
#  171: 'sir',
#  172: 'nor',
#  173: 'without',
#  174: 'sort',
#  175: 'thought',
#  176: 'part',
#  177: 'night',
#  178: 'cried',
#  179: 'know',
#  180: 'oh',
#  181: 'right',
#  182: 'once',
#  183: 'god',
#  184: 'aye',
#  185: 'boats',
#  186: 'air',
#  187: 'crew',
#  188: 'whole',
#  189: 'half',
#  190: 'against',
#  191: '\n\n\n\n',
#  192: 'tell',
#  193: 'thus',
#  194: 'things',
#  195: 'thee',
#  196: 'soon',
#  197: 'take',
#  198: 'each',
#  199: 'came',
#  200: 'small',
#  201: 'whaling',
#  202: 'hands',
#  203: 'feet',
#  204: 'mast',
#  205: 'something',
#  206: 'both',
#  207: 'full',
#  208: 'between',
#  209: 'till',
#  210: 'under',
#  211: 'think',
#  212: 'just',
#  213: 'place',
#  214: 'why',
#  215: 'towards',
#  216: 'she',
#  217: 'thy',
#  218: 'nothing',
#  219: 'found',
#  220: 'called',
#  221: 'times',
#  222: 'another',
#  223: 'along',
#  224: 'poor',
#  225: 'make',
#  226: 'body',
#  227: 'flask',
#  228: 'high',
#  229: 'heard',
#  230: 'sight',
#  231: 'moment',
#  232: "'ll",
#  233: 'saw',
#  234: 'stand',
#  235: 'end',
#  236: 'sun',
#  237: 'strange',
#  238: 'does',
#  239: 'hold',
#  240: 'sail',
#  241: 'new',
#  242: 'went',
#  243: 'voyage',
#  244: 'get',
#  245: 'face',
#  246: 'however',
#  247: 'years',
#  248: 'few',
#  249: 'black',
#  250: 'because',
#  251: 'dead',
#  252: 'shall',
#  253: 'stood',
#  254: 'going',
#  255: 'indeed',
#  256: 'am',
#  257: 'perhaps',
#  258: 'nantucket',
#  259: 'certain',
#  260: 'also',
#  261: 'whether',
#  262: 'death',
#  263: 'iron',
#  264: 'leg',
#  265: 'eye',
#  266: 'arm',
#  267: 'seems',
#  268: 'heart',
#  269: 'oil',
#  270: 'ships',
#  271: 'heads',
#  272: 'true',
#  273: 'wild',
#  274: 'seas',
#  275: 'matter',
#  276: 'whose',
#  277: 'sometimes',
#  278: 'cabin',
#  279: 'leviathan',
#  280: 'hard',
#  281: 'itself',
#  282: 'seem',
#  283: 'moby',
#  284: 'soul',
#  285: 'give',
#  286: 'jonah',
#  287: 'standing',
#  288: 'dick',
#  289: 'sailor',
#  290: 'days',
#  291: 'always',
#  292: 'young',
#  293: 'present',
#  294: 'ere',
#  295: 'harpooneer',
#  296: 'mind',
#  297: 'light',
#  298: 'land',
#  299: 'within',
#  300: 'enough',
#  301: 'harpoon',
#  302: 'bed',
#  303: 'tail',
#  304: 'instant',
#  305: 'known',
#  306: 'mate',
#  307: 'bildad',
#  308: 'lay',
#  309: 'large',
#  310: 'beneath',
#  311: 'length',
#  312: 'set',
#  313: 'morning',
#  314: 'done',
#  315: 'least',
#  316: 'peleg',
#  317: 'put',
#  318: 'fire',
#  319: 'pip',
#  320: 'yes',
#  321: 'open',
#  322: 'four',
#  323: 'word',
#  324: 'often',
#  325: 'ocean',
#  326: 'board',
#  327: 'whalemen',
#  328: 'case',
#  329: 'living',
#  330: 'looking',
#  331: 'point',
#  332: 'general',
#  333: 'rather',
#  334: 'waters',
#  335: 'business',
#  336: 'vast',
#  337: 'left',
#  338: 'deep',
#  339: 'name',
#  340: 'wind',
#  341: 'keep',
#  342: 'top',
#  343: 'myself',
#  344: 'turned',
#  345: 'therefore',
#  346: 'best',
#  347: 'having',
#  348: 'since',
#  349: 'reason',
#  350: 'looked',
#  351: 'near',
#  352: 'work',
#  353: 'better',
#  354: 'boy',
#  355: 'lord',
#  356: 'fishery',
#  357: 'fast',
#  358: 'lower',
#  359: 'order',
#  360: 'further',
#  361: 'hear',
#  362: 'together',
#  363: 'turn',
#  364: 'live',
#  365: 'blood',
#  366: 'second',
#  367: 'short',
#  368: 'fine',
#  369: 'book',
#  370: 'mr.',
#  371: 'spout',
#  372: 'themselves',
#  373: 'chase',
#  374: 'watch',
#  375: 'broad',
#  376: 'rope',
#  377: 'dark',
#  378: 'room',
#  379: 'above',
#  380: 'king',
#  381: 'mouth',
#  382: 'indian',
#  383: 'feel',
#  384: 'ivory',
#  385: 'jaw',
#  386: 'next',
#  387: 'aloft',
#  388: 'savage',
#  389: 'harpooneers',
#  390: 'entire',
#  391: 'peculiar',
#  392: 'tashtego',
#  393: 'find',
#  394: 'gone',
#  395: 'goes',
#  396: 'craft',
#  397: 'bottom',
#  398: 'mark',
#  399: 'home',
#  400: 'curious',
#  401: 'ground',
#  402: 'call',
#  403: 'try',
#  404: 'grand',
#  405: 'fellow',
#  406: 'devil',
#  407: 'began',
#  408: 'comes',
#  409: 'coming',
#  410: 'sailors',
#  411: 'run',
#  412: 'cut',
#  413: 'turning',
#  414: 'close',
#  415: 'green',
#  416: 'less',
#  417: 'forth',
#  418: 'rest',
#  419: 'slowly',
#  420: 'main',
#  421: 'vessel',
#  422: 'stern',
#  423: 'forward',
#  424: 'coffin',
#  425: 'thousand',
#  426: 'taking',
#  427: 'speak',
#  428: 'heaven',
#  429: 'nevertheless',
#  430: 'broken',
#  431: 'bone',
#  432: 'sharks',
#  433: 'suddenly',
#  434: 'story',
#  435: 'cook',
#  436: 'took',
#  437: 'hundred',
#  438: 'common',
#  439: 'bows',
#  440: 'taken',
#  441: 'below',
#  442: 'particular',
#  443: 'besides',
#  444: 'wide',
#  445: 'teeth',
#  446: 'used',
#  447: 'stranger',
#  448: 'carpenter',
#  449: 'waves',
#  450: 'quarter',
#  451: 'behind',
#  452: 'struck',
#  453: 'kept',
#  454: 'ten',
#  455: 'sleep',
#  456: 'else',
#  457: 'monster',
#  458: 'voice',
#  459: 'fact',
#  460: 'got',
#  461: 'running',
#  462: 'several',
#  463: 'lost',
#  464: 'bones',
#  465: 'english',
#  466: 'pull',
#  467: 'people',
#  468: 'straight',
#  469: 'blue',
#  470: 'making',
#  471: 'view',
#  472: 'sure',
#  473: 'mighty',
#  474: 'chance',
#  475: 'whaleman',
#  476: 'whatever',
#  477: 'especially',
#  478: 'nigh',
#  479: 'house',
#  480: 'door',
#  481: 'lance',
#  482: 'sat',
#  483: 'touching',
#  484: 'means',
#  485: 'knew',
#  486: 'somehow',
#  487: 'anything',
#  488: 'rolled',
#  489: 'queer',
#  490: 'says',
#  491: 'seamen',
#  492: 'five',
#  493: 'hole',
#  494: 'sudden',
#  495: 'form',
#  496: 'bow',
#  497: 'noble',
#  498: 'hours',
#  499: 'told',
#  500: 'passed',
#  501: 'mine',
#  502: 'caught',
#  503: 'creature',
#  504: 'earth',
#  505: 'wondrous',
#  506: 'surface',
#  507: 'quite',
#  508: 'parts',
#  509: 'whom',
#  510: 'felt',
#  511: 'course',
#  512: 'sound',
#  513: 'brow',
#  514: 'sails',
#  515: 'mortal',
#  516: 'cape',
#  517: 'red',
#  518: 'hour',
#  519: 'sharp',
#  520: 'alone',
#  521: 'ready',
#  522: "'em",
#  523: 'saying',
#  524: 'clear',
#  525: 'concerning',
#  526: 'hat',
#  527: 'mates',
#  528: 'calm',
#  529: 'nature',
#  530: 'steelkilt',
#  531: 'single',
#  532: 'easy',
#  533: 'purpose',
#  534: 'wake',
#  535: 'coast',
#  536: 'wo',
#  537: 'pipe',
#  538: 'mere',
#  539: 'makes',
#  540: 'art',
#  541: 'gold',
#  542: 'oars',
#  543: 'mean',
#  544: 'others',
#  545: 'various',
#  546: 'sailed',
#  547: 'low',
#  548: 'mass',
#  549: 'plain',
#  550: 'cry',
#  551: 'darted',
#  552: 'gave',
#  553: 'plainly',
#  554: 'power',
#  555: 'object',
#  556: 'distance',
#  557: 'de',
#  558: 'chief',
#  559: 'forecastle',
#  560: 'bear',
#  561: 'quick',
#  562: 'famous',
#  563: 'suppose',
#  564: 'lines',
#  565: 'human',
#  566: 'table',
#  567: 'forehead',
#  568: 'help',
#  569: 'held',
#  570: 'skin',
#  571: 'leaving',
#  572: 'seeing',
#  573: 'flukes',
#  574: 'heavy',
#  575: 'arms',
#  576: 'cutting',
#  577: 'aspect',
#  578: 'daggoo',
#  579: 'gentlemen',
#  580: 'fixed',
#  581: 'bulwarks',
#  582: 'legs',
#  583: 'either',
#  584: 'wonder',
#  585: 'brought',
#  586: 'middle',
#  587: 'sign',
#  588: 'ha',
#  589: 'manner',
#  590: 'unknown',
#  591: 'placed',
#  592: 'truth',
#  593: 'sky',
#  594: 'born',
#  595: 'use',
#  596: 'given',
#  597: 'natural',
#  598: 'shot',
#  599: 'previous',
#  600: 'around',
#  601: 'holding',
#  602: 'weather',
#  603: 'wood',
#  604: 'fell',
#  605: 'turns',
#  606: 'loose',
#  607: 'strong',
#  608: 'town',
#  609: 'boys',
#  610: 'spring',
#  611: 'fair',
#  612: 'none',
#  613: 'thoughts',
#  614: 'rolling',
#  615: 'hope',
#  616: 'remained',
#  617: 'twenty',
#  618: 'skeleton',
#  619: 'start',
#  620: 'brain',
#  621: 'sailing',
#  622: 'greenland',
#  623: 'fin',
#  624: 'blubber',
#  625: 'nearly',
#  626: 'rigging',
#  627: 'american',
#  628: 'creatures',
#  629: 'idea',
#  630: 'stop',
#  631: 'foot',
#  632: 'landlord',
#  633: 'want',
#  634: 'company',
#  635: 'mad',
#  636: 'completely',
#  637: 'hardly',
#  638: 'rose',
#  639: 'account',
#  640: 'island',
#  641: 'pacific',
#  642: 'already',
#  643: 'darkness',
#  644: 'visible',
#  645: 'kill',
#  646: 'ashore',
#  647: 'hammock',
#  648: 'fear',
#  649: 'drawing',
#  650: 'during',
#  651: 'third',
#  652: 'show',
#  653: 'steel',
#  654: 'proper',
#  655: 'hence',
#  656: 'nose',
#  657: 'intervals',
#  658: 'hull',
#  659: 'ago',
#  660: 'considering',
#  661: 'bulk',
#  662: 'cold',
#  663: 'harpoons',
#  664: 'jet',
#  665: 'tossed',
#  666: 'passage',
#  667: 'fifty',
#  668: 'forty',
#  669: 'planks',
#  670: 'knife',
#  671: "'ve",
#  672: 'ca',
#  673: 'soft',
#  674: 'doubt',
#  675: 'fresh',
#  676: 'ho',
#  677: 'substance',
#  678: 'cast',
#  679: 'helm',
#  680: 'across',
#  681: 'woe',
#  682: 'aft',
#  683: 'except',
#  684: "d'ye",
#  685: 'instances',
#  686: 'rising',
#  687: 'upper',
#  688: 'possibly',
#  689: 'smoke',
#  690: 'vain',
#  691: 'act',
#  692: 'really',
#  693: 'snow',
#  694: 'horn',
#  695: 'flying',
#  696: 'hung',
#  697: 'storm',
#  698: 'carried',
#  699: 'pass',
#  700: 'strike',
#  701: 'o',
#  702: 'die',
#  703: 'free',
#  704: 'suspended',
#  705: 'shark',
#  706: 'hammer',
#  707: 'species',
#  708: 'hoisted',
#  709: 'unless',
#  710: 'astern',
#  711: 'battle',
#  712: 'nay',
#  713: 'words',
#  714: 'works',
#  715: 'final',
#  716: 'stands',
#  717: 'mariners',
#  718: 'generally',
#  719: 'six',
#  720: 'certainly',
#  721: 'possible',
#  722: 'lamp',
#  723: 'touch',
#  724: 'question',
#  725: 'killed',
#  726: 'sideways',
#  727: 'pointed',
#  728: 'strangely',
#  729: 'leeward',
#  730: 'pole',
#  731: 'leaning',
#  732: 'miles',
#  733: 'knows',
#  734: 'mild',
#  735: 'huge',
#  736: 'late',
#  737: 'meanwhile',
#  738: 'i.',
#  739: 'gods',
#  740: 'supper',
#  741: 'shipmates',
#  742: 'become',
#  743: 'person',
#  744: 'thinking',
#  745: 'pretty',
#  746: 'entirely',
#  747: 'aside',
#  748: 'glance',
#  749: 'thunder',
#  750: 'swimming',
#  751: 'hunters',
#  752: 'oar',
#  753: 'seated',
#  754: 'bound',
#  755: 'south',
#  756: 'bit',
#  757: 'coat',
#  758: 'royal',
#  759: 'believe',
#  760: 'started',
#  761: 'ice',
#  762: 'thick',
#  763: 'wooden',
#  764: 'sides',
#  765: 'altogether',
#  766: 'hump',
#  767: 'feeling',
#  768: 'eyeing',
#  769: 'lightning',
#  770: 'giving',
#  771: 'pilot',
#  772: 'looks',
#  773: 'fishermen',
#  774: 'overboard',
#  775: 'scene',
#  776: 'read',
#  777: 'command',
#  778: 'ancient',
#  779: 'dropped',
#  780: 'wholly',
#  781: 'hast',
#  782: 'steady',
#  783: 'alongside',
#  784: 'play',
#  785: 'whiteness',
#  786: 'fedallah',
#  787: 'precisely',
#  788: 'cruising',
#  789: 'degree',
#  790: 'silent',
#  791: 'yourself',
#  792: 'considerable',
#  793: 'horse',
#  794: 'finally',
#  795: 'drawn',
#  796: 'circumstances',
#  797: 'port',
#  798: 'followed',
#  799: 'ears',
#  800: 'lie',
#  801: 'midnight',
#  802: 'hair',
#  803: 'fancy',
#  804: 'jaws',
#  805: 'somewhat',
#  806: 'chest',
#  807: 'getting',
#  808: "'m",
#  809: 'otherwise',
#  810: 'thirty',
#  811: 'war',
#  812: 'circumstance',
#  813: 'alive',
#  814: 'gale',
#  815: 'sweet',
#  816: 'wise',
#  817: 'hearts',
#  818: 'father',
#  819: 'state',
#  820: 'friend',
#  821: 'bodily',
#  822: 'according',
#  823: 'ahead',
#  824: 'blow',
#  825: 'parsee',
#  826: 'watery',
#  827: 'drop',
#  828: 'kind',
#  829: 'afterwards',
#  830: 'talk',
#  831: 'masts',
#  832: 'enormous',
#  833: 'cases',
#  834: 'number',
#  835: 'received',
#  836: 'interval',
#  837: 'duty',
#  838: 'similar',
#  839: 'skull',
#  840: 'takes',
#  841: 'wife',
#  842: 'year',
#  843: 'headed',
#  844: 'complete',
#  845: 'keel',
#  846: 'bearing',
#  847: 'hinted',
#  848: 'spread',
#  849: 'vessels',
#  850: 'eight',
#  851: 'yards',
#  852: 'sword',
#  853: 'honour',
#  854: 'orders',
#  855: 'captains',
#  856: 'fore',
#  857: 'answer',
#  858: 'exactly',
#  859: 'following',
#  860: 'became',
#  861: 'beyond',
#  862: 'tall',
#  863: 'fiery',
#  864: 'floating',
#  865: 'dart',
#  866: 'wall',
#  867: 'swift',
#  868: 'added',
#  869: 'seldom',
#  870: 'owing',
#  871: 'self',
#  872: 'carry',
#  873: 'instead',
#  874: 'beat',
#  875: 'front',
#  876: 'learned',
#  877: 'escape',
#  878: 'circle',
#  879: 'strength',
#  880: 'thyself',
#  881: 'secret',
#  882: 'remains',
#  883: 'hunt',
#  884: 'level',
#  885: 'dutch',
#  886: 'pulling',
#  887: 'country',
#  888: 'ai',
#  889: 'perils',
#  890: 'love',
#  891: 'bright',
#  892: 'negro',
#  893: 'spot',
#  894: 'warm',
#  895: 'lances',
#  896: 'flew',
#  897: 'higher',
#  898: 'break',
#  899: 'somewhere',
#  900: 'thrown',
#  901: 'yellow',
#  902: 'hot',
#  903: 'passing',
#  904: 'real',
#  905: 'hidden',
#  906: 'meantime',
#  907: 'pagan',
#  908: 'ran',
#  909: 'instantly',
#  910: 'commanded',
#  911: 'flesh',
#  912: 'burst',
#  913: 'regarded',
#  914: 'regular',
#  915: 'speaking',
#  916: 'consider',
#  917: 'different',
#  918: 'remain',
#  919: 'scuttle',
#  920: 'gazing',
#  921: 'st.',
#  922: 'lakeman',
#  923: 'shore',
#  924: 'east',
#  925: 'grow',
#  926: 'formed',
#  927: 'sitting',
#  928: 'wonderful',
#  929: 'centre',
#  930: 'filled',
#  931: 'sleeping',
#  932: 'pursuit',
#  933: 'cause',
#  934: 'striking',
#  935: 'likewise',
#  936: 'jacket',
#  937: 'terrible',
#  938: 'drew',
#  939: 'deadly',
#  940: 'hint',
#  941: 'step',
#  942: 'descried',
#  943: 'lad',
#  944: 'master',
#  945: 'souls',
#  946: 'post',
#  947: 'nantucketer',
#  948: 'seventy',
#  949: 'sink',
#  950: 'dashed',
#  951: 'log',
#  952: 'windlass',
#  953: 'advance',
#  954: 'golden',
#  955: 'tis',
#  956: 'radney',
#  957: 'rear',
#  958: 'distant',
#  959: 'winds',
#  960: 'decks',
#  961: 'jolly',
#  962: 'bag',
#  963: 'original',
#  964: 'worse',
#  965: 'lives',
#  966: 'repeated',
#  967: 'truly',
#  968: "'d",
#  969: 'minutes',
#  970: 'spare',
#  971: 'stove',
#  972: 'anchor',
#  973: 'aboard',
#  974: 'empty',
#  975: 'quickly',
#  976: 'lofty',
#  977: 'age',
#  978: 'terrors',
#  979: 'laid',
#  980: 'base',
#  981: 'french',
#  982: 'invested',
#  983: 'windward',
#  984: 'evinced',
#  985: 'attached',
#  986: 'terror',
#  987: 'beheld',
#  988: 'gunwale',
#  989: 'blacksmith',
#  990: 'virtue',
#  991: 'hollow',
#  992: 'lies',
#  993: 'tree',
#  994: 'holy',
#  995: 'separate',
#  996: 'needs',
#  997: 'thinks',
#  998: 'ah',
#  999: 'swung',
#  1000: 'inches',
#  ...}

# %% [markdown]
# #### using a for loop, for i in sequences[0], print the tokenizer.index_word

# %%
for i in sequences[0]:
    print(str(i) + " : " + tokenizer.index_word[i])
# Out:
# 158 : chapter
# 9443 : 1
# 17526 : loomings
# 402 : call
# 42 : me
# 1043 : ishmael
# 43 : some
# 247 : years
# 659 : ago
# 140 : never
# 296 : mind
# 116 : how
# 82 : long
# 787 : precisely
# 347 : having
# 113 : little
# 36 : or
# 50 : no
# 1788 : money
# 6 : in
# 49 : my
# 3028 : purse
# 3 : and
# 218 : nothing
# 442 : particular
# 5 : to

# %% [markdown]
# #### print the tokenizer.word_counts

# %%
print(tokenizer.word_counts)
# Out:
# OrderedDict([('chapter', 4447), ('1', 28), ('loomings', 3), ('call', 1382), ('me', 16095), ('ishmael', 500), ('some', 15789), ('years', 2400), ('ago', 815), ('never', 5262), ('mind', 2039), ('how', 6330), ('long', 8567), ('precisely', 690), ('having', 1679), ('little', 6412), ('or', 17879), ('no', 14916), ('money', 305), ('in', 105799), ('my', 15231), ('purse', 178), ('and', 164029), ('nothing', 2936), ('particular', 1273), ('to', 117832), ('interest', 442), ('on', 26910), ('shore', 572), ('i', 53430), ('thought', 3874), ('would', 11232), ('sail', 2522), ('about', 7982), ('a', 119756), ('see', 6734), ('the', 367474), ('watery', 650), ('part', 3874), ('of', 168116), ('world', 4420), ('it', 64056), ('is', 43758), ('way', 6942), ('have', 19604), ('driving', 234), ('off', 5642), ('spleen', 26), ('regulating', 26), ('circulation', 26), ('whenever', 390), ('find', 1404), ('myself', 1716), ('growing', 234), ('grim', 286), ('mouth', 1456), ('damp', 234), ('drizzly', 26), ('november', 52), ('soul', 2132), ('involuntarily', 312), ('pausing', 260), ('before', 7644), ('coffin', 1300), ('warehouses', 52), ('bringing', 260), ('up', 13151), ('rear', 546), ('every', 5850), ('funeral', 130), ('meet', 468), ('especially', 1144), ('hypos', 26), ('get', 2470), ('such', 9542), ('an', 15262), ('upper', 780), ('hand', 5434), ('that', 78532), ('requires', 156), ('strong', 884), ('moral', 78), ('principle', 234), ('prevent', 130), ('from', 27872), ('deliberately', 208), ('stepping', 182), ('into', 13442), ('street', 312), ('methodically', 78), ('knocking', 182), ('people', 1170), ("'s", 44772), ('hats', 104), ('then', 16172), ('account', 832), ('high', 2756), ('time', 8632), ('sea', 11310), ('as', 44564), ('soon', 3328), ('can', 6838), ('this', 35620), ('substitute', 78), ('for', 41184), ('pistol', 156), ('ball', 286), ('with', 43966), ('philosophical', 26), ('flourish', 78), ('cato', 26), ('throws', 78), ('himself', 5252), ('upon', 14586), ('his', 64792), ('sword', 624), ('quietly', 494), ('take', 3302), ('ship', 13182), ('there', 21580), ('surprising', 182), ('if', 12298), ('they', 16848), ('but', 46254), ('knew', 1118), ('almost', 5018), ('all', 39052), ('men', 6240), ('their', 15704), ('degree', 676), ('other', 10608), ('cherish', 234), ('very', 8268), ('nearly', 858), ('same', 5460), ('feelings', 156), ('towards', 2938), ('ocean', 1846), ('now', 20124), ('your', 6292), ('insular', 104), ('city', 364), ('manhattoes', 26), ('belted', 78), ('round', 6344), ('by', 30524), ('wharves', 130), ('indian', 1456), ('isles', 442), ('coral', 182), ('reefs', 26), ('commerce', 156), ('surrounds', 52), ('her', 8466), ('surf', 130), ('right', 3770), ('left', 1742), ('streets', 364), ('you', 22906), ('waterward', 52), ('its', 9646), ('extreme', 338), ('downtown', 26), ('battery', 78), ('where', 5460), ('noble', 1092), ('mole', 78), ('washed', 104), ('waves', 1222), ('cooled', 52), ('breezes', 104), ('which', 16224), ('few', 2392), ('hours', 1092), ('previous', 910), ('were', 17550), ('out', 13572), ('sight', 2704), ('land', 2002), ('look', 5200), ('at', 33846), ('crowds', 130), ('water', 4706), ('gazers', 26), ('circumambulate', 26), ('dreamy', 104), ('sabbath', 104), ('afternoon', 234), ('go', 4940), ('corlears', 26), ('hook', 468), ('coenties', 26), ('slip', 104), ('thence', 182), ('whitehall', 26), ('northward', 78), ('what', 15574), ('do', 10738), ('see?--posted', 26), ('like', 16562), ('silent', 676), ('sentinels', 26), ('around', 910), ('town', 884), ('stand', 2600), ('thousands', 416), ('mortal', 1040), ('fixed', 936), ('reveries', 156), ('leaning', 728), ('against', 3458), ('spiles', 26), ('seated', 702), ('pier', 26), ('heads', 2184), ('looking', 1820), ('over', 10478), ('bulwarks', 936), ('ships', 2210), ('china', 234), ('aloft', 1430), ('rigging', 858), ('striving', 260), ('still', 8086), ('better', 1612), ('seaward', 52), ('peep', 208), ('these', 10166), ('are', 15236), ('landsmen', 260), ('week', 130), ('days', 2080), ('pent', 52), ('lath', 26), ('pla ...

# %% [markdown]
# #### get the len of tokenizer.word_counts and assign it to a variable called vocabulary_size

# %%
vocabulary_size = len(tokenizer.word_counts)

# %% [markdown]
# ### Convert to Numpy Matrix

# %%
import numpy as np

# %% [markdown]
# #### Create a numpy array with the seqences and call it sequences

# %%
sequences = np.array(sequences)

# %% [markdown]
# #### print the sequences

# %%
print(sequences)
# Out:
# [[  158  9443 17526 ...   218   442     5]
#  [ 9443 17526   402 ...   442     5  1165]
#  [17526   402    42 ...     5  1165    42]
#  ...
#  [  240   938   351 ...  1419  1313    74]
#  [  938   351  1418 ...  1313    74   219]
#  [  351  1418     3 ...    74   219   222]]

# %% [markdown]
# # Creating an LSTM based model

# %% [markdown]
# #### import keras, Sequential, Dense, LSTM, and Embedding

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding

# %% [markdown]
# #### def a function called:  create_model(vocabulary_size, seq_len): <br> in the model add a sequential model, add (Embedding(vocabulary_size, 25, input_length=seq_len), add (LSTM(150, return_sequences=True), add (LSTM(150), add (Dense(150, activation='relu'), Dense(vocabulary_size, activation='softmax')<br> then compile the model using; loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'] <br> finally, print the summary of the model and return the model.

# %%
def create_model(vocabulary_size, seq_len):
    
    # your code goes here
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150, activation='relu'))
    model.add(Dense(vocabulary_size, activation='softmax'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# ### Train / Test Split

# %% [markdown]
# #### import to_categorical from from tensorflow.keras.utils

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# #### display the sequences

# %%
sequences
# Out:
# array([[  158,  9443, 17526, ...,   218,   442,     5],
#        [ 9443, 17526,   402, ...,   442,     5,  1165],
#        [17526,   402,    42, ...,     5,  1165,    42],
#        ...,
#        [  240,   938,   351, ...,  1419,  1313,    74],
#        [  938,   351,  1418, ...,  1313,    74,   219],
#        [  351,  1418,     3, ...,    74,   219,   222]])

# %% [markdown]
# #### now, display the first 49

# %%
sequences[:,:-1]
# Out:
# array([[  158,  9443, 17526, ...,     3,   218,   442],
#        [ 9443, 17526,   402, ...,   218,   442,     5],
#        [17526,   402,    42, ...,   442,     5,  1165],
#        ...,
#        [  240,   938,   351, ...,    84,  1419,  1313],
#        [  938,   351,  1418, ...,  1419,  1313,    74],
#        [  351,  1418,     3, ...,  1313,    74,   219]])

# %% [markdown]
# #### now display the last word only

# %%
# last Word
sequences[:,-1]
# Out:
# array([   5, 1165,   42, ...,   74,  219,  222])

# %% [markdown]
# #### assing the sequences to the variables X, and y

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
seq_len
# Out:
# 25

# %% [markdown]
# ### Training the Model

# %% [markdown]
# #### define the model

# %%
model = create_model(vocabulary_size+1, seq_len)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 25, 25)            438175
#
#  lstm (LSTM)                 (None, 25, 150)           105600
#
#  lstm_1 (LSTM)               (None, 150)               180600
#
#  dense (Dense)               (None, 150)               22650
#
#  dense_1 (Dense)             (None, 17527)             2646577
#
# =================================================================
# Total params: 3,393,602
# Trainable params: 3,393,602
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---
#
# ----

# %% [markdown]
# #### import dump,load from pickle

# %%
from pickle import dump

# %%
#### fit the model using X, y, batch_size=128, epochs=5,verbose=1

# %%
len(y) / 25
# Out:
# 8587.28

# %%
model.fit(X, y, batch_size=128, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 1678/1678 [==============================] - 432s 254ms/step - loss: 0.0083 - accuracy: 0.0633
# Epoch 2/5
# 1678/1678 [==============================] - 401s 239ms/step - loss: 4.6370e-04 - accuracy: 0.0641
# Epoch 3/5
# 1678/1678 [==============================] - 390s 233ms/step - loss: 4.6661e-04 - accuracy: 0.0649
# Epoch 4/5
# 1678/1678 [==============================] - 393s 234ms/step - loss: 4.6678e-04 - accuracy: 0.0653
# Epoch 5/5
# 1678/1678 [==============================] - 395s 235ms/step - loss: 4.6539e-04 - accuracy: 0.0654

# %% [markdown]
# #### save the model to file and call it: newtext.h5

# %%
model.save('newtext.h5')

# %% [markdown]
# #### save the tokenizer

# %%
dump(tokenizer, open('newtext', 'wb'))

# %% [markdown]
# # Generating New Text

# %% [markdown]
# #### import: randint from random, load from pickle,  load_model from keras.models and pad_sequences

# %%
from random import randint
from pickle import load
from keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# #### run this function below

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''
    
    # Final Output
    output_text = []
    
    # Intial Seed Sequence
    input_text = seed_text
    
    # Create num_gen_words
    for i in range(num_gen_words):
        
        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        
        # Pad sequences to our trained rate (50 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')
        
        # Predict Class Probabilities for each word - Original
        #pred_word_ind = model.predict_classes(pad_encoded, verbose=0)[0]
        
        #good one so far: 
        pred_word_ind = (model.predict(pad_encoded) > 0.5).astype("int32")
        
        #pred_word_ind = (model.predict(pad_encoded)).astype("int32")
        #pred_word_ind = (model.predict(pad_encoded) > 0.5)
        
        # Grab word
        #pred_word = tokenizer.index_word[pred_word_ind] 
        pred_word = (tokenizer.index_word[pred_word_ind])
        
        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word
        
        output_text.append(pred_word)
        
    # Make it look like a sentence.
    return ' '.join(output_text)

# %% [markdown]
# ### Grab a random seed sequence. For instance text_sequences[0]

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['he',
#  'recognised',
#  'his',
#  'cutting',
#  'spade',
#  'pole',
#  'entangled',
#  'in',
#  'the',
#  'lines',
#  'that',
#  'were',
#  'knotted',
#  'round',
#  'the',
#  'tail',
#  'of',
#  'one',
#  'of',
#  'these',
#  'whales',
#  'there',
#  "'s",
#  'a',
#  'pretty',
#  'fellow']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# "he recognised his cutting spade pole entangled in the lines that were knotted round the tail of one of these whales there 's a pretty fellow"

# %% [markdown]
# ### Exploring Generated Sequence

# %% [markdown]
# #### create a variable called full_text and read the file: moby_dick_four_chapters.txt

# %%
full_text = read_file('moby_dick_four_chapters.txt')

# %%
for i,word in enumerate(full_text.split()):
    if word == 'inkling':
        print(' '.join(full_text.split()[i-20:i+20]))
        print('\n')
# Out:
# were stains of some sort or other. At first I knew not what to make of this; but soon an inkling of the truth occurred to me. I remembered a story of a white man--a whaleman too--who, falling among the

# %% [markdown]
# #### That's the end
